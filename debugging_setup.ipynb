# %%
import sys
print(sys.executable)
# Out:
# /home/samuel76/.conda/envs/stat542/bin/python

# %%
import torch
print(torch.__file__)
# Out:
# /home/samuel76/.conda/envs/stat542/lib/python3.11/site-packages/torch/__init__.py

# %%
print(f"GPU Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")
    print(f"CUDA Capability: {torch.cuda.get_device_capability(0)}")
else:
    print("WARNING: No GPU detected! Go to Runtime > Change runtime type > Select GPU")
# Out:
# GPU Available: True
# GPU Name: NVIDIA H200 NVL
# GPU Memory: 139.81 GB
# CUDA Capability: (9, 0)
